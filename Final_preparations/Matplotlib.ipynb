# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
import pandas as pd




# Load the dataset
df = pd.read_csv('your_dataset.csv')

# Display the first few rows of the dataframe
print(df.head())

# Display summary statistics
print(df.describe())

# Check for missing values
print(df.isnull().sum())

# Visualize the distribution of numerical features
numerical_features = df.select_dtypes(include=['int64', 'float64']).columns
for feature in numerical_features:
    plt.figure(figsize=(10, 4))
    sns.histplot(df[feature], kde=True)
    plt.title(f'Distribution of {feature}')
    plt.show()

# Visualize relationships between numerical features
sns.pairplot(df[numerical_features])
plt.show()

# Visualize the correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# Analyze categorical features
categorical_features = df.select_dtypes(include=['object']).columns
for feature in categorical_features:
    plt.figure(figsize=(10, 4))
    sns.countplot(x=df[feature])
    plt.title(f'Count plot of {feature}')
    plt.show()

# Summarize insights
# (You can add your own insights based on the visualizations)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 8
#       2 import pandas as pd
#       7 # Load the dataset
# ----> 8 df = pd.read_csv('your_dataset.csv')
#      10 # Display the first few rows of the dataframe
#      11 print(df.head())
#
# ...

# %%
#Line chart
x=[1,2,3,4]
y=[6,7,8,9]
plt.plot(x,y,marker='o',linestyle='-')
plt.title("Line graph")
plt.xlabel("Number")
plt.ylabel("Y axis")
plt.show()

# %%
import numpy as np

data= np.random.randn(1000)
x_axis=[100,200,300,500,1000]
y_axis=[100,200,300,500,1000]

# plt.yticks(np.arange(0, 100, 10))

# %%
plt.figure(figsize=(10,6))

plt.subplot(1,2,1)
plt.hist(data, bins=10, color='black', edgecolor='white', alpha=0.8)
plt.xlabel('Value')
plt.savefig("My_plt1.png")
plt.ylabel('Frequency')
plt.title("Histogram")


plt.subplot(1,2,2)
plt.scatter(x_axis,y_axis,color='red',marker='o',label='Data Points')
plt.xlabel("X Axis")
plt.savefig("My_plt2.png")
plt.ylabel("Y Axis")
plt.legend()

plt.figure(figsize=(10,6))
plt.subplot(2,2,2)
plt.scatter(x_axis,y_axis,color='red',marker='o',label='Data Points')
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.legend()

plt.savefig("My_plt.png")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Create a sample dataset
np.random.seed(0) #This ensures that the random numbers generated by NumPy are the same every time you run the code (for reproducibility).
x = np.random.rand(100) #Generates 100 random numbers between 0 and 1. This is used as the x variable (independent variable).
y = 2 * x + np.random.normal(0, 0.1, 100) # Linear relation with some noise.␣The noise is sampled from a normal distribution with mean 0 and standard␣deviation 0.1.
# Convert data to a pandas DataFrame
data = pd.DataFrame({'x': x, 'y': y}) #creates a Pandas DataFrame where x and y␣are stored as columns.
# Create the regression plot
sns.regplot(x='x', y='y', data=data)
# Display the plot
plt.show()

# %%
# %pip install plotly

import seaborn as sns
import plotly.express as px
import pandas as pd
# Sample data (replace this with your own dataset)
data = {
'x': [1, 2, 3, 4, 5],
'y': [10, 11, 8, 5, 7],
'size': [30, 80, 50, 20, 70],
'category': ['A', 'B', 'A', 'B', 'A']
}
df = pd.DataFrame(data)
# Use Seaborn to create a stylish scatter plot (aesthetic customization)
sns.set(style="whitegrid")
sns.scatterplot(x='x', y='y', hue='category', size='size', sizes=(30, 200),data=df, palette='Set1')
# Use Plotly Express to add interactivity to the Seaborn plot
fig = px.scatter(df, x='x', y='y', size='size', color='category',color_discrete_sequence=px.colors.qualitative.Set1,labels={'color': 'Category'},title='Interactive Scatter Plot')
# Customize the appearance further if needed
fig.update_traces(marker=dict(line=dict(width=2, color='DarkSlateGrey')),selector=dict(mode='markers+text'))

# Show the interactive plot
fig.show()
# Out:
# ...
#   Using cached plotly-5.24.1-py3-none-any.whl.metadata (7.3 kB)
# ...
#   Using cached tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# ...
# Using cached plotly-5.24.1-py3-none-any.whl (19.1 MB)
# Using cached tenacity-9.0.0-py3-none-any.whl (28 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 23
#      20 fig.update_traces(marker=dict(line=dict(width=2, color='DarkSlateGrey')),selector=dict(mode='markers+text'))
#      22 # Show the interactive plot
# ---> 23 fig.show()
#
# File ~/My_data/3rd_Semester/.venv/lib/python3.13/site-packages/plotly/basedatatypes.py:3410, in BaseFigure.show(self, *args, **kwargs)
#    3377 """
#    3378 Show a figure using either the default renderer(s) or the renderer(s)
#    3379 specified by the renderer argument
#    (...)
#    3406 None
#    3407 """
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
# Set up the figure and axis
fig, ax = plt.subplots()
xdata, ydata = [], []
scatter = ax.scatter([], [])
# Function to initialize the plot
def init():
    ax.set_xlim(0, 2 * np.pi)
    ax.set_ylim(-1.5, 1.5)
    return scatter,
# Function to update the plot in each frame
def update(frame):
    x = np.linspace(0, 2 * np.pi, 100)
    y = np.sin(x + 0.1 * frame) # Vary the phase for animation



    scatter.set_offsets(np.column_stack((x, y)))
    return scatter,
# Create the animation
ani = FuncAnimation(fig, update, frames=50, init_func=init, blit=True)
# Display the animation as an HTML5 video in the notebook
HTML(ani.to_html5_video())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 26
#      24 ani = FuncAnimation(fig, update, frames=50, init_func=init, blit=True)
#      25 # Display the animation as an HTML5 video in the notebook
# ---> 26 HTML(ani.to_html5_video())
#
# File ~/miniconda3/lib/python3.12/site-packages/matplotlib/animation.py:1265, in Animation.to_html5_video(self, embed_limit)
#    1262 path = Path(tmpdir, "temp.m4v")
#    1263 # We create a writer manually so that we can get the
#    1264 # appropriate size for the tag
# -> 1265 Writer = writers[mpl.rcParams['animation.writer']]
#    1266 writer = Writer(codec='h264',
#    1267                 bitrate=mpl.rcParams['animation.bitrate'],
#    1268                 fps=1000. / self._interval)
#    1269 self.save(str(path), writer=writer)
#
# ...

# %%
import csv

file=pd.read_csv("StudentGradesAndPrograms.csv")
Df=pd.DataFrame(file)
Df
# Out:
# /tmp/ipykernel_132621/2209051096.py:3: DtypeWarning:
#
# Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#        schoolyear gradeLevel classPeriod classType  \
# 0       2024-2025         07           1       ELE
# 1       2024-2025         07           1       ELE
# 2       2024-2025         07           1       ELE
# 3       2024-2025         07           1       ELE
# 4       2024-2025         07           1       ELE
# ...           ...        ...         ...       ...
# 200989  2024-2025         06           1       ELE
# 200990  2024-2025         07           3       ENG
# 200991  2024-2025         05           7       SOC
# 200992  2024-2025         04           8       SCI
# 200993  2024-2025         07           2       SCI
#
#                            schoolName  gradePercentage avid sped migrant ell  \
# 0                    West Junior High           2000.0    Y    N       N   N
# ...

# %%
Df.head()
# Out:
#   schoolyear gradeLevel classPeriod classType        schoolName  \
# 0  2024-2025         07           1       ELE  West Junior High
# 1  2024-2025         07           1       ELE  West Junior High
# 2  2024-2025         07           1       ELE  West Junior High
# 3  2024-2025         07           1       ELE  West Junior High
# 4  2024-2025         07           1       ELE  West Junior High
#
#    gradePercentage avid sped migrant ell student_ID
# 0           2000.0    Y    N       N   N  0HRJHI993
# 1           2000.0    N    N       N   N  CKN322II4
# 2           1950.0    N    N       N   N  V523OZUH8
# 3           1850.0    Y    N       N   N  OJDYS3434
# 4           1500.0    N    N       Y   Y  49RSM3UF6

# %%
Df.describe()
# Out:
#        gradePercentage
# count    200994.000000
# mean         81.183078
# std          24.594533
# min           0.000000
# 25%          72.800000
# 50%          88.500000
# 75%          97.900000
# max        2000.000000

# %%
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200994 entries, 0 to 200993
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   schoolyear       200994 non-null  object
#  1   gradeLevel       200994 non-null  object
#  2   classPeriod      200994 non-null  object
#  3   classType        200994 non-null  object
#  4   schoolName       200994 non-null  object
#  5   gradePercentage  200994 non-null  float64
#  6   avid             200994 non-null  object
#  7   sped             200994 non-null  object
#  8   migrant          200994 non-null  object
#  9   ell              200994 non-null  object
#  10  student_ID       200994 non-null  object
# dtypes: float64(1), object(10)
# memory usage: 16.9+ MB

# %%
null_values=Df.isnull().sum()
null_values
# Out:
# schoolyear         0
# gradeLevel         0
# classPeriod        0
# classType          0
# schoolName         0
# gradePercentage    0
# avid               0
# sped               0
# migrant            0
# ell                0
# student_ID         0
# dtype: int64

# %%
# Out:
#        schoolyear gradeLevel classPeriod classType  \
# 0       2024-2025         07           1       ELE
# 1       2024-2025         07           1       ELE
# 2       2024-2025         07           1       ELE
# 3       2024-2025         07           1       ELE
# 4       2024-2025         07           1       ELE
# ...           ...        ...         ...       ...
# 200989  2024-2025         06           1       ELE
# 200990  2024-2025         07           3       ENG
# 200991  2024-2025         05           7       SOC
# 200992  2024-2025         04           8       SCI
# 200993  2024-2025         07           2       SCI
#
#                            schoolName  gradePercentage avid sped migrant ell  \
# 0                    West Junior High           2000.0    Y    N       N   N
# 1                    West Junior High           2000.0    N    N       N   N
# 2                    West Junior High           1950.0    N    N       N   N
# ...

# %%
#checking if the outlier exist or not
sns.boxenplot(Df['gradePercentage'])
# Out:
# <Axes: ylabel='gradePercentage'>

# %%
Q1=Df['gradePercentage'].quantile(0.25)
Q3=Df['gradePercentage'].quantile(0.75)

IQR=Q3-Q1

upper_limit=Q3 +1.5 *IQR
lower_limit=Q1 -1.5 *IQR
value=Df[(Df['gradePercentage'] < upper_limit) & (Df['gradePercentage']>lower_limit)]
value
# Out:
#        schoolyear gradeLevel classPeriod classType  \
# 98      2023-2024         06           2       ELE
# 99      2023-2024         06           2       ELE
# 100     2023-2024         06           2       ELE
# 101     2018-2019         07           7       ELE
# 102     2018-2019         06           7       ELE
# ...           ...        ...         ...       ...
# 189458  2021-2022         07           5       MAT
# 189459  2023-2024         05           8       ENG
# 189460  2024-2025         03           6       ENG
# 189461  2024-2025         07           3       SCI
# 189462  2018-2019         08           4       ENG
#
#                              schoolName  gradePercentage avid sped migrant  \
# 98                    North Junior High           135.20    Y    Y       N
# 99                    North Junior High           135.20    Y    N       N
# 100                   North Junior High           135.20    Y    N       N
# ...

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.histplot(Df['gradePercentage'])

plt.subplot(2,2,2)
sns.boxenplot(Df['gradePercentage'])

plt.subplot(2,2,3)
sns.histplot(value['gradePercentage'])

plt.subplot(2,2,4)
sns.boxenplot(value['gradePercentage'])
# Out:
# <Axes: ylabel='gradePercentage'>

# %%
# Select only the numerical columns
numerical_columns = value.select_dtypes(include=['int64', 'float64']).columns
value_min_max_scaled = (value[numerical_columns] - value[numerical_columns].min()) / (value[numerical_columns].max() - value[numerical_columns].min())
value_min_max_scaled
# Out:
#         gradePercentage
# 98             1.000000
# 99             1.000000
# 100            1.000000
# 101            0.994001
# 102            0.994001
# ...                 ...
# 189458         0.000200
# 189459         0.000200
# 189460         0.000200
# 189461         0.000200
# 189462         0.000000
#
# [189365 rows x 1 columns]

# %%
value
value['gradeLevel'].unique()
# Out:
# array(['06', '07', '08', '04', '02', 'KG', '05', '03', '01', 'UE'],
#       dtype=object)

# %%
Df['classPeriod'].fillna(Df.mean(), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 Df['classPeriod'].fillna(Df.mean(), inplace=True)
#
# NameError: name 'Df' is not defined
