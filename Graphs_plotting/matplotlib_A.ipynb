# %%
import matplotlib.pyplot as plt
x1=[1,2,3]
x2=[7,8,3]
y=[50,5,6]
plt.scatter(x1,x2,y)
plt.legend('raees')

# %%
#Figure plot for representing multiple graphs at a position

#plt.subplot(number of rows,number of graphs on a row/number of columns, position of graph)
